# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-4.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from datasets) (3.20.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from datasets) (2.4.1)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-23.0.0-cp314-cp314-win_amd64.whl.metadata (3.1 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Downloading dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.6.0-cp314-cp314-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.19 (from datasets)
#   Downloading multiprocess-0.70.18-py313-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.10.0,>=2023.1.0 (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting huggingface-hub<2.0,>=0.25.0 (from datasets)
#   Downloading huggingface_hub-1.3.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from datasets) (6.0.3)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading aiohttp-3.13.3-cp314-cp314-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: anyio in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=0.25.0->datasets)
#   Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Collecting shellingham (from huggingface-hub<2.0,>=0.25.0->datasets)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting typer-slim (from huggingface-hub<2.0,>=0.25.0->datasets)
#   Downloading typer_slim-0.21.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading propcache-0.4.1-cp314-cp314-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets)
#   Downloading yarl-1.22.0-cp314-cp314-win_amd64.whl.metadata (77 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: colorama in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Collecting click>=8.0.0 (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Downloading datasets-4.5.0-py3-none-any.whl (515 kB)
# Downloading dill-0.4.0-py3-none-any.whl (119 kB)
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Downloading huggingface_hub-1.3.4-py3-none-any.whl (536 kB)
# Downloading xxhash-3.6.0-cp314-cp314-win_amd64.whl (32 kB)
# Installing collected packages: xxhash, shellingham, pyarrow, propcache, multidict, hf-xet, fsspec, frozenlist, dill, click, aiohappyeyeballs, yarl, typer-slim, multiprocess, aiosignal, huggingface-hub, aiohttp, datasets
#
#    ---- -----------------------------------  2/18 [pyarrow]
#    ---- -----------------------------------  2/18 [pyarrow]
#    ---- -----------------------------------  2/18 [pyarrow]
#    ---- -----------------------------------  2/18 [pyarrow]
#    ---- -----------------------------------  2/18 [pyarrow]
#    ---- -----------------------------------  2/18 [pyarrow]
#    ---- -----------------------------------  2/18 [pyarrow]
#   Attempting uninstall: fsspec
#    ---- -----------------------------------  2/18 [pyarrow]
#     Found existing installation: fsspec 2026.1.0
#    ---- -----------------------------------  2/18 [pyarrow]
#     Uninstalling fsspec-2026.1.0:
#    ---- -----------------------------------  2/18 [pyarrow]
#       Successfully uninstalled fsspec-2026.1.0
#    ---- -----------------------------------  2/18 [pyarrow]
#    ------------- --------------------------  6/18 [fsspec]
#    ------------- --------------------------  6/18 [fsspec]
#    -------------------- -------------------  9/18 [click]
#    -------------------------- ------------- 12/18 [typer-slim]
#    ---------------------------- ----------- 13/18 [multiprocess]
#    --------------------------------- ------ 15/18 [huggingface-hub]
#    --------------------------------- ------ 15/18 [huggingface-hub]
#    --------------------------------- ------ 15/18 [huggingface-hub]
#    ----------------------------------- ---- 16/18 [aiohttp]
#    ----------------------------------- ---- 16/18 [aiohttp]
#    ------------------------------------- -- 17/18 [datasets]
#    ------------------------------------- -- 17/18 [datasets]
#    ------------------------------------- -- 17/18 [datasets]
#    ---------------------------------------- 18/18 [datasets]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 click-8.3.1 datasets-4.5.0 dill-0.4.0 frozenlist-1.8.0 fsspec-2025.10.0 hf-xet-1.2.0 huggingface-hub-1.3.4 multidict-6.7.1 multiprocess-0.70.18 propcache-0.4.1 pyarrow-23.0.0 shellingham-1.5.4 typer-slim-0.21.1 xxhash-3.6.0 yarl-1.22.0
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Scarico il dataset delle review dei film

# %%
from datasets import load_dataset
dataset = load_dataset('stanfordnlp/imdb')

# %%
training_dataset = dataset['train']
test_dataset = dataset['test'].shuffle(seed=42).select(range(2000))

# %%
print(f"Righe di training: {len(training_dataset)}")
print(f"Righe di test: {len(test_dataset)}")
print("Esempio:", training_dataset[0])
# Out:
# Righe di training: 25000
# Righe di test: 2000
# Esempio: {'text': 'I rented I AM CURIOUS-YELLOW from my video store because of all the controversy that surrounded it when it was first released in 1967. I also heard that at first it was seized by U.S. customs if it ever tried to enter this country, therefore being a fan of films considered "controversial" I really had to see this for myself.<br /><br />The plot is centered around a young Swedish drama student named Lena who wants to learn everything she can about life. In particular she wants to focus her attentions to making some sort of documentary on what the average Swede thought about certain political issues such as the Vietnam War and race issues in the United States. In between asking politicians and ordinary denizens of Stockholm about their opinions on politics, she has sex with her drama teacher, classmates, and married men.<br /><br />What kills me about I AM CURIOUS-YELLOW is that 40 years ago, this was considered pornographic. Really, the sex and nudity scenes are few and far between, even then it\'s not shot like some cheaply made porno. While my countrymen mind find it shocking, in reality sex and nudity are a major staple in Swedish cinema. Even Ingmar Bergman, arguably their answer to good old boy John Ford, had sex scenes in his films.<br /><br />I do commend the filmmakers for the fact that any sex shown in the film is shown for artistic purposes rather than just to shock people and make money to be shown in pornographic theaters in America. I AM CURIOUS-YELLOW is a good film for anyone wanting to study the meat and potatoes (no pun intended) of Swedish cinema. But really, this film doesn\'t have much of a plot.', 'label': 0}

# %% [markdown]
# ## Preprocessiamo il testo. Creiamo il vocabolario e i dataloader

# %%
import torch
import torch.nn as nn
import string
from torch.utils.data import DataLoader
from datasets import load_dataset
from collections import Counter
from torch.nn.utils.rnn import pad_sequence

# 1. Carichiamo il dataset
dataset = load_dataset("stanfordnlp/imdb")

# 2. Creiamo il Vocabolario a partire dal tokenizzatore che semplicemente divide in parole e toglie la punteggiatura
def tokenizer(text):
    # Rimuove punteggiatura e mette minuscolo
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text.lower().split()


#Contiamo il numero di parole per selezionare solo le più frequenti
counter = Counter()
for text in dataset['train']['text']:
    counter.update(tokenizer(text.lower()))

# Teniamo solo le 25.000 parole più frequenti e creiamo il vocabolario
vocab = {word: i+2 for i, (word, _) in enumerate(counter.most_common(25000))}
vocab['<PAD>'] = 0  # Padding (riempitivo)
vocab['<UNK>'] = 1  # Unknown (parole sconosciute)

# Funzione per convertire testo in indici
def text_pipeline(text):
    #Se non trova il token lo sostituisce con '<UNK>'
    return [vocab.get(token, 1) for token in tokenizer(text.lower())]

# 3. Collate Function (Per gestire batch con frasi di lunghezza diversa)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#la funzione di collate è una funzione di trasformazione del
def collate_batch(batch):
    label_list, text_list = [], []
    for _item in batch:
        # Trasformiamo il testo in numeri
        processed_text = torch.tensor(text_pipeline(_item['text']), dtype=torch.int64)
        text_list.append(processed_text)
        label_list.append(_item['label'])

    label_list = torch.tensor(label_list, dtype=torch.float32).to(device)
    # pad_sequence aggiunge zeri alle frasi più corte per pareggiare la lunghezza. Lo zero corriponde all'indice del token <PAD>
    text_list = pad_sequence(text_list, batch_first=True, padding_value=0).to(device)
    return text_list, label_list

# Creiamo i DataLoader
train_loader = DataLoader(dataset['train'], batch_size=64, shuffle=True, collate_fn=collate_batch)
test_loader = DataLoader(dataset['test'], batch_size=64, shuffle=False, collate_fn=collate_batch)

# %% [markdown]
# ## Definiamo ora la rete RNN

# %%
class RNNClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, output_dim, dropout_rate=0.1):
        super(RNNClassifier, self).__init__()

        # 1. Embedding: Trasforma l'indice (es. 45) in un vettore denso
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)

        # 2. LSTM Layer
        # batch_first=True significa che l'input è (batch, seq_len, features)
        self.rnn = nn.LSTM(embed_dim, hidden_dim, bidirectional=True,
                            batch_first=True)

        # 3. Fully Connected Layer (Output). Devo moltiplicare l'hidden_dim per 2 perchè la rete è bidirezionale
        self.fc = nn.Linear(hidden_dim * 2, output_dim)

        #Il dropout serve a regolarizzare la rete. Praticamente spegne il dropout_rate per cento dei neuroni ad ogni iterazione
        self.dropout = nn.Dropout(dropout_rate)
        # 4. Sigmoide (per ottenere probabilità tra 0 e 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, text):
        # text shape: [batch_size, seq_len]
        embedded = self.embedding(text)

        # rnn output: [batch_size, seq_len, hidden_dim]
        #hidden ha shape: [num_layers * num_directions, batch_size, hidden_dim]
        output, (hidden, cell) = self.rnn(embedded)
        hidden_forward = hidden[-2,:,:]
        hidden_backward = hidden[-1,:,]
        hidden_final = torch.cat((hidden_forward, hidden_backward), dim=1)
        # shape risultante: [batch_size, hidden_dim * 2]

        return self.sigmoid(self.fc(hidden_final))

# Iperparametri
VOCAB_SIZE = len(vocab)
EMBED_DIM = 64
HIDDEN_DIM = 128
OUTPUT_DIM = 1 # 1 perché è classificazione binaria (0 o 1)

model = RNNClassifier(VOCAB_SIZE, EMBED_DIM, HIDDEN_DIM, OUTPUT_DIM).to(device)
print(model)
# Out:
# RNNClassifier(
#   (embedding): Embedding(25002, 64, padding_idx=0)
#   (rnn): LSTM(64, 128, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# ## Creo il loop di training

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.BCELoss()

def train_one_epoch(model, iterator, optimizer, criterion):
    model.train()
    epoch_loss = 0
    epoch_acc = 0

    for text, labels in iterator:
        optimizer.zero_grad()

        # Forward pass
        # output shape: [64, 1]
        # labels shape: [64]
        # Devo fare lo squueze sull'output per trasformarlo da matrice a vettore!
        predictions = model(text).squeeze(1)

        # Calcolo loss e accuracy
        loss = criterion(predictions, labels)
        rounded_preds = torch.round(predictions)
        correct = (rounded_preds == labels).float()
        acc = correct.sum() / len(correct)

        # Backward pass
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# ## Creo la funzione di valutazione dell'accuratezza

# %%
def evaluate(model, iterator, criterion):
    # Mette il modello in modalità "valutazione"
    # (spegne Dropout )
    model.eval()

    epoch_loss = 0
    epoch_acc = 0

    # Disabilita il calcolo dei gradienti (velocizza e risparmia RAM)
    with torch.no_grad():

        for text, labels in iterator:
            # Forward pass
            predictions = model(text).squeeze(1)

            # Calcolo loss
            loss = criterion(predictions, labels)

            # Calcolo accuracy
            rounded_preds = torch.round(predictions)
            correct = (rounded_preds == labels).float()
            acc = correct.sum() / len(correct)

            epoch_loss += loss.item()
            epoch_acc += acc.item()

    return epoch_loss / len(iterator), epoch_acc / len(iterator)

# %% [markdown]
# ## Imposto il training loop

# %%
import time

N_EPOCHS = 5

for epoch in range(N_EPOCHS):

    start_time = time.time()

    # 1. Addestramento
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion)

    # 2. Valutazione
    test_loss, test_acc = evaluate(model, test_loader, criterion)

    end_time = time.time()
    mins, secs = divmod(end_time - start_time, 60)

    print(f'Epoch: {epoch+1:02} | Time: {int(mins)}m {int(secs)}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\tTest  Loss: {test_loss:.3f} | Test  Acc: {test_acc*100:.2f}%')
# Out:
# Epoch: 01 | Time: 0m 18s
# 	Train Loss: 0.356 | Train Acc: 84.87%
# 	Test  Loss: 0.384 | Test  Acc: 83.35%
# Epoch: 02 | Time: 0m 19s
# 	Train Loss: 0.258 | Train Acc: 90.10%
# 	Test  Loss: 0.361 | Test  Acc: 84.51%
# Epoch: 03 | Time: 0m 20s
# 	Train Loss: 0.206 | Train Acc: 92.47%
# 	Test  Loss: 0.354 | Test  Acc: 86.08%
# Epoch: 04 | Time: 0m 19s
# 	Train Loss: 0.168 | Train Acc: 94.10%
# 	Test  Loss: 0.443 | Test  Acc: 83.72%
# Epoch: 05 | Time: 0m 19s
# 	Train Loss: 0.135 | Train Acc: 95.65%
# 	Test  Loss: 0.398 | Test  Acc: 86.28%

# %%
def predict_sentiment(model, sentence, vocab, device):
    model.eval() # Importante: spegne il Dropout per avere risultati stabili

    # 1. Tokenizzazione (uguale a quella fatta nel training)
    tokens = sentence.lower().split()

    # 2. Convertiamo parole in numeri
    # Se la parola non è nel vocabolario, usiamo l'indice 1 (<UNK>)
    indexed = [vocab.get(t, 1) for t in tokens]


    # 3. Trasformiamo in Tensore PyTorch
    tensor = torch.LongTensor(indexed).to(device)

    # 4. Aggiungiamo la dimensione del Batch
    # Il modello si aspetta [batch_size, seq_len], noi abbiamo solo [seq_len].
    # unsqueeze(0) trasforma [10] in [1, 10]
    tensor = tensor.unsqueeze(0)

    # 5. Predizione
    with torch.no_grad():
        prediction = model(tensor)

    # Restituiamo il valore float (da 0 a 1)
    return prediction.item()

# %%
# Definiamo alcune frasi di test
test_sentences = [
    "This movie is absolutely fantastic and wonderful",  # Chiaramente Positiva
    "The plot was boring and the acting was terrible",   # Chiaramente Negativa
    "It was not bad, actually quite good",               # Complessa (doppia negazione/contrasto)
    "I wasted two hours of my life",                     # Negativa indiretta
    "A masterpiece"                                      # Molto corta
]

print("-" * 50)
print(f"{'FRASE':<50} | {'SCORE':<10} | {'SENTIMENT'}")
print("-" * 50)

for sentence in test_sentences:
    score = predict_sentiment(model, sentence, vocab, device)

    # Interpretazione semplice dello score
    if score >= 0.5:
        label = "POSITIVO"
    else:
        label = "NEGATIVO "

    print(f"{sentence[:47]:<50}... | {score:.4f}     | {label}")
# Out:
# --------------------------------------------------
# FRASE                                              | SCORE      | SENTIMENT
# --------------------------------------------------
# This movie is absolutely fantastic and wonderfu   ... | 0.8241     | POSITIVO
# The plot was boring and the acting was terrible   ... | 0.0035     | NEGATIVO
# It was not bad, actually quite good               ... | 0.0718     | NEGATIVO
# I wasted two hours of my life                     ... | 0.0796     | NEGATIVO
# A masterpiece                                     ... | 0.9401     | POSITIVO

# %% [markdown]
# It was not bad, actually quite good               ... | 0.3572     | NEGATIVO
#
# Qui il modello è abbastanza confuso e sbaglia. Stiamo re-imparando non solo la semantica ma anche la sintassi dell'inglese. Possiamo ora al posto di allenare la matrice degli embedding usare glove, dove già le parole hanno una loro rappresentazione semantica.

# %%
# !pip install torchtext
# Out:
# Collecting torchtext
#   Downloading torchtext-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torchtext) (4.67.1)
# Requirement already satisfied: requests in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torchtext) (2.32.5)
# Requirement already satisfied: torch in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torchtext) (2.10.0+cu128)
# Requirement already satisfied: numpy in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torchtext) (2.4.1)
# Requirement already satisfied: six in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torchtext) (1.17.0)
# Collecting sentencepiece (from torchtext)
#   Downloading sentencepiece-0.2.1-cp314-cp314-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from requests->torchtext) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from requests->torchtext) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from requests->torchtext) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from requests->torchtext) (2026.1.4)
# Requirement already satisfied: filelock in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torch->torchtext) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torch->torchtext) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torch->torchtext) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torch->torchtext) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torch->torchtext) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torch->torchtext) (2025.10.0)
# Requirement already satisfied: setuptools in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from torch->torchtext) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from sympy>=1.13.3->torch->torchtext) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from jinja2->torch->torchtext) (3.0.3)
# Requirement already satisfied: colorama in c:\users\andre\pycharmprojects\corso_ai\.venv\lib\site-packages (from tqdm->torchtext) (0.4.6)
# Downloading torchtext-0.6.0-py3-none-any.whl (64 kB)
# Downloading sentencepiece-0.2.1-cp314-cp314-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 9.0 MB/s eta 0:00:00
# Installing collected packages: sentencepiece, torchtext
#
#    ---------------------------------------- 2/2 [torchtext]
#
# Successfully installed sentencepiece-0.2.1 torchtext-0.6.0
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torchtext

# 1. Scarichiamo i vettori GloVe (versione 6B, 100 dimensioni)
print("Scaricando GloVe...")
glove = torchtext.vocab.GloVe(name='6B', dim=100)

# 2. Creiamo la matrice dei pesi
embedding_matrix = torch.zeros((len(vocab), 100))

print("Creazione matrice dei pesi...")
hit = 0
miss = 0

for word, index in vocab.items():
    # Se la parola è nel vocabolario di GloVe, prendiamo il suo vettore
    if word in glove.stoi:
        embedding_matrix[index] = glove[word]
        hit += 1
    else:
        # Se non c'è (es. <PAD>, <UNK> o nomi strani), lasciamo zeri o inizializziamo random
        # Qui lasciamo random normal per <UNK>)
        if word == '<UNK>':
             embedding_matrix[index] = torch.randn(100)
        miss += 1

print(f"Parole trovate in GloVe: {hit}, Non trovate: {miss}")
# Out:
# Scaricando GloVe...
# Creazione matrice dei pesi...
# Parole trovate in GloVe: 22987, Non trovate: 2015

# %%
# Aggiorniamo la dimensione dell'embedding a 100
EMBED_DIM = 100
HIDDEN_DIM = 64
# Ricreiamo il modello con la nuova dimensione
model = RNNClassifier(len(vocab), EMBED_DIM, HIDDEN_DIM, OUTPUT_DIM, dropout_rate=0.5).to(device)

# Copiamo i pesi di GloVe dentro il layer di embedding del modello
model.embedding.weight.data.copy_(embedding_matrix)

# Gestione <PAD>: Il padding deve rimanere sempre zero, non deve imparare nulla
model.embedding.weight.data[vocab['<PAD>']] = torch.zeros(EMBED_DIM)

print("Pesi GloVe caricati con successo!")
# Out:
# Pesi GloVe caricati con successo!

# %% [markdown]
# Aggiungiamo il learning decay e il salvataggio del miglior modello ad ogni iterazione

# %%
import time
from torch.optim.lr_scheduler import ReduceLROnPlateau
N_EPOCHS = 10
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
best_valid_loss = float('inf')
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.66, patience=2)
for epoch in range(N_EPOCHS):

    start_time = time.time()

    # 1. Addestramento
    train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion)

    # 2. Valutazione
    test_loss, test_acc = evaluate(model, test_loader, criterion)
    scheduler.step(test_loss)

    if test_loss < best_valid_loss:
        best_valid_loss = test_loss
        # Salviamo i pesi su disco
        torch.save(model.state_dict(), './model/miglior_modello_imdb.pt')
        print(f'Epoch: {epoch+1:02} | Nuovo Record! Modello salvato (Loss: {test_loss:.3f})')
    else:
        print(f'Epoch: {epoch+1:02} | Nessun miglioramento.')
    end_time = time.time()
    mins, secs = divmod(end_time - start_time, 60)

    print(f'Epoch: {epoch+1:02} | Time: {int(mins)}m {int(secs)}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train Acc: {train_acc*100:.2f}%')
    print(f'\tTest  Loss: {test_loss:.3f} | Test  Acc: {test_acc*100:.2f}%')
# Out:
# Epoch: 01 | Nuovo Record! Modello salvato (Loss: 0.504)
# Epoch: 01 | Time: 0m 10s
# 	Train Loss: 0.640 | Train Acc: 63.31%
# 	Test  Loss: 0.504 | Test  Acc: 77.49%
# Epoch: 02 | Nuovo Record! Modello salvato (Loss: 0.405)
# Epoch: 02 | Time: 0m 10s
# 	Train Loss: 0.512 | Train Acc: 76.12%
# 	Test  Loss: 0.405 | Test  Acc: 83.27%
# Epoch: 03 | Nuovo Record! Modello salvato (Loss: 0.316)
# Epoch: 03 | Time: 0m 10s
# 	Train Loss: 0.310 | Train Acc: 87.76%
# 	Test  Loss: 0.316 | Test  Acc: 87.38%
# Epoch: 04 | Nessun miglioramento.
# Epoch: 04 | Time: 0m 9s
# 	Train Loss: 0.226 | Train Acc: 91.66%
# 	Test  Loss: 0.325 | Test  Acc: 86.61%
# Epoch: 05 | Nessun miglioramento.
# Epoch: 05 | Time: 0m 8s
# 	Train Loss: 0.139 | Train Acc: 95.53%
# 	Test  Loss: 0.351 | Test  Acc: 87.05%
# Epoch: 06 | Nessun miglioramento.
# Epoch: 06 | Time: 0m 8s
# 	Train Loss: 0.086 | Train Acc: 97.53%
# 	Test  Loss: 0.406 | Test  Acc: 86.06%
# Epoch: 07 | Nessun miglioramento.
# Epoch: 07 | Time: 0m 8s
# 	Train Loss: 0.054 | Train Acc: 98.75%
# 	Test  Loss: 0.498 | Test  Acc: 86.30%
# Epoch: 08 | Nessun miglioramento.
# Epoch: 08 | Time: 0m 9s
# 	Train Loss: 0.039 | Train Acc: 99.16%
# 	Test  Loss: 0.506 | Test  Acc: 85.62%
# Epoch: 09 | Nessun miglioramento.
# Epoch: 09 | Time: 0m 9s
# 	Train Loss: 0.033 | Train Acc: 99.32%
# 	Test  Loss: 0.566 | Test  Acc: 85.14%
# Epoch: 10 | Nessun miglioramento.
# Epoch: 10 | Time: 0m 8s
# 	Train Loss: 0.026 | Train Acc: 99.53%
# 	Test  Loss: 0.572 | Test  Acc: 85.12%

# %%
# 1. Ricrea l'architettura
model = RNNClassifier(len(vocab), 100, HIDDEN_DIM, OUTPUT_DIM, 0.1).to(device)

# 2. Carica i pesi dal file
model.load_state_dict(torch.load('./model/miglior_modello_imdb.pt'))
model.eval() # Metti in eval mode

print("Modello caricato con successo!")

# 3. Riprova la frase trappola
frase = "It was not bad, actually quite good"
score = predict_sentiment(model, frase, vocab, device)
print(f"Score finale: {score:.4f}")
# Out:
# Modello caricato con successo!
# Score finale: 0.5189
